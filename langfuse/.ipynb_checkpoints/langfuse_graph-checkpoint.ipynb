# %% [markdown]
# ## LanGraph

# %%
# import
from langfuse import Langfuse
import openai
import os 
os.environ["LANGFUSE_PUBLIC_KEY"] = "pk-lf-fdf17b7f-cdd4-491a-8dfd-0275a4d243be"
os.environ["LANGFUSE_SECRET_KEY"] = "sk-lf-bc01c094-4d80-44ce-882c-28f53a01ae5b"
os.environ["LANGFUSE_HOST"] = "http://localhost:3000"


from langfuse import Langfuse
langfuse = Langfuse()
 
# optional, verify that Langfuse is configured correctly
langfuse.auth_check()
# Out:
# True

# %%
# !pip install langgraph -q

# %%
from typing import Annotated
 
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from typing_extensions import TypedDict
 
from langgraph.graph import StateGraph
from langgraph.graph.message import add_messages

# %%
class State(TypedDict):
    # Messages have the type "list". The `add_messages` function in the annotation defines how this state key should be updated
    # (in this case, it appends messages to the list, rather than overwriting them)
    messages: Annotated[list, add_messages]



graph_builder = StateGraph(State)
 
llm = ChatOpenAI(model = "gpt-4o", temperature = 0.2)
 
# The chatbot node function takes the current State as input and returns an updated messages list. This is the basic pattern for all LangGraph node functions.
def chatbot(state: State):
    return {"messages": [llm.invoke(state["messages"])]}
 
# Add a "chatbot" node. Nodes represent units of work. They are typically regular python functions.
graph_builder.add_node("chatbot", chatbot)
 
# Add an entry point. This tells our graph where to start its work each time we run it.
graph_builder.set_entry_point("chatbot")
 
# Set a finish point. This instructs the graph "any time this node is run, you can exit."
graph_builder.set_finish_point("chatbot")
 
# To be able to run our graph, call "compile()" on the graph builder. This creates a "CompiledGraph" we can use invoke on our state.
graph = graph_builder.compile()

# %%
from langfuse.callback import CallbackHandler
 
# Initialize Langfuse CallbackHandler for Langchain (tracing)
langfuse_handler = CallbackHandler()
 
for s in graph.stream({"messages": [HumanMessage(content = "Langfuse가 뭐야?")]},
                      config={"callbacks": [langfuse_handler]}):
    print(s)
# Out:
# {'chatbot': {'messages': [AIMessage(content='Langfuse는 자연어 처리(NLP) 애플리케이션을 구축하고 관리하는 데 도움을 주는 도구입니다. 이 도구는 다양한 언어 모델과 API를 통합하여, 개발자가 복잡한 NLP 작업을 더 쉽게 구현할 수 있도록 지원합니다. Langfuse는 주로 다음과 같은 기능을 제공합니다:\n\n1. **통합 관리**: 여러 언어 모델과 API를 한 곳에서 관리할 수 있습니다.\n2. **모니터링**: NLP 애플리케이션의 성능과 상태를 실시간으로 모니터링할 수 있습니다.\n3. **분석**: 데이터 분석 도구를 통해 애플리케이션의 성능을 평가하고 개선할 수 있습니다.\n4. **확장성**: 다양한 언어 모델을 쉽게 추가하고 확장할 수 있습니다.\n\n이러한 기능을 통해 Langfuse는 NLP 애플리케이션 개발자들이 더 효율적으로 작업할 수 있도록 도와줍니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 212, 'prompt_tokens': 14, 'total_tokens': 226, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_e375328146', 'finish_reason': 'stop', 'logprobs': None}, id='run-241e56ac-9d8f-40a2-915a-0aeac4b0e31c-0', usage_metadata={'input_tokens': 14, 'output_tokens': 212, 'total_tokens': 226})]}}

# %%
from IPython.display import Image, display
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Multiagent application

# %%
# !pip install langgraph langchain langchain_openai langchain_experimental pandas wikipedia -q

# %%
from typing import Annotated
 
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper
from datetime import datetime
from langchain.tools import Tool
 
# Define a tools that searches Wikipedia
wikipedia_tool = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper())
 
# Define a new tool that returns the current datetime
datetime_tool = Tool(
    name="Datetime",
    func = lambda x: datetime.now().isoformat(),
    description="현재 시간을 반환",
)

# %%
from langchain.agents import AgentExecutor, create_openai_tools_agent
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_openai import ChatOpenAI
 
def create_agent(llm: ChatOpenAI, system_prompt: str, tools: list):
    # Each worker node will be given a name and some tools.
    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                system_prompt,
            ),
            MessagesPlaceholder(variable_name="messages"),
            MessagesPlaceholder(variable_name="agent_scratchpad"),
        ]
    )
    agent = create_openai_tools_agent(llm, tools, prompt)
    executor = AgentExecutor(agent=agent, tools=tools)
    return executor
 
def agent_node(state, agent, name):
    result = agent.invoke(state)
    return {"messages": [HumanMessage(content=result["output"], name=name)]}

# %%
from langchain_core.output_parsers.openai_functions import JsonOutputFunctionsParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
 
members = ["Researcher", "CurrentTime"]
system_prompt = (
    "너는 두 사람의 대화를 관리하는 사람이야. 모두 한글로 진행해줘. "
    " 두 사람은 이 사람들이이야:{members}. 이들의 요구에 따라 어떤 사람이 일해야할지 선택하고 일을 시켜."
    " 각 사람은 각자의 task를 실행하고 그 실행 결과를 반환해줘."
    " 모든게 끝나면, FINISH로 응답"
)
# Our team supervisor is an LLM node. It just picks the next agent to process and decides when the work is completed
options = ["FINISH"] + members
 
# Using openai function calling can make output parsing easier for us
function_def = {
    "name": "route",
    "description": "다음 역할 지정.",
    "parameters": {
        "title": "routeSchema",
        "type": "object",
        "properties": {
            "next": {
                "title": "Next",
                "anyOf": [
                    {"enum": options},
                ],
            }
        },
        "required": ["next"],
    },
}
 
# Create the prompt using ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        MessagesPlaceholder(variable_name="messages"),
        (
            "system",
            "이 대화의 흐름에 따르면, 누가 다음으로 말해야 해?"
            " 아니면 대화 종료? FINISH? 여기 중에 선택해봐. {options}",
        ),
    ]
).partial(options=str(options), members=", ".join(members))
 
llm = ChatOpenAI(model="gpt-4o")
 
# Construction of the chain for the supervisor agent
supervisor_chain = (
    prompt
    | llm.bind_functions(functions=[function_def], function_call="route")
    | JsonOutputFunctionsParser()
)

# %%
import functools
import operator
from typing import Sequence, TypedDict
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langgraph.graph import END, StateGraph, START
 
# The agent state is the input to each node in the graph
class AgentState(TypedDict):
    # The annotation tells the graph that new messages will always be added to the current states
    messages: Annotated[Sequence[BaseMessage], operator.add]
    # The 'next' field indicates where to route to next
    next: str
 
# Add the research agent using the create_agent helper function
research_agent = create_agent(llm, "너는 웹 조사하는 사람이야. ", [wikipedia_tool])
research_node = functools.partial(agent_node, agent=research_agent, name="Researcher")
 
# Add the time agent using the create_agent helper function
currenttime_agent = create_agent(llm, "현 시각을 알려줄 수 있어 ", [datetime_tool])
currenttime_node = functools.partial(agent_node, agent=currenttime_agent, name = "CurrentTime")
 
workflow = StateGraph(AgentState)
 
# Add a "chatbot" node. Nodes represent units of work. They are typically regular python functions.
workflow.add_node("Researcher", research_node)
workflow.add_node("CurrentTime", currenttime_node)
workflow.add_node("supervisor", supervisor_chain)
 
# We want our workers to ALWAYS "report back" to the supervisor when done
for member in members:
    workflow.add_edge(member, "supervisor")
 
# Conditional edges usually contain "if" statements to route to different nodes depending on the current graph state.
# These functions receive the current graph state and return a string or list of strings indicating which node(s) to call next.
conditional_map = {k: k for k in members}
conditional_map["FINISH"] = END
workflow.add_conditional_edges("supervisor", lambda x: x["next"], conditional_map)
 
# Add an entry point. This tells our graph where to start its work each time we run it.
workflow.add_edge(START, "supervisor")
 
# To be able to run our graph, call "compile()" on the graph builder. This creates a "CompiledGraph" we can use invoke on our state.
graph_2 = workflow.compile()

# %%
from langfuse.callback import CallbackHandler
 
# Initialize Langfuse CallbackHandler for Langchain (tracing)
langfuse_handler = CallbackHandler()
 
# Add Langfuse handler as callback: config={"callbacks": [langfuse_handler]}
for s in graph_2.stream({"messages": [HumanMessage(content = "미국은 어떤 시간대를 쓰고 미국은 몇시야?")]},
                      config={"callbacks": [langfuse_handler]}):
    print(s)
    print("----")
# Out:
# {'supervisor': {'next': 'Researcher'}}
# ----
# {'Researcher': {'messages': [HumanMessage(content='미국은 총 9개의 표준 시간대를 사용합니다. 이 시간대는 대부분의 주가 봄, 여름, 가을 동안 일광 절약 시간제(DST)를 준수하고 있습니다. 시간대와 일광 절약 시간제 규정은 미국 교통부에서 관리합니다.\n\n### 미국의 시간대\n1. **동부 표준시 (EST)**\n2. **중부 표준시 (CST)**\n3. **산악 표준시 (MST)**\n4. **태평양 표준시 (PST)**\n5. **알래스카 표준시 (AKST)**\n6. **하와이-알류샨 표준시 (HAST)**\n7. **대서양 표준시 (AST)**\n8. **사모아 표준시 (SST)**\n9. **채머로 표준시 (ChST)**\n\n일광 절약 시간제는 대부분의 주에서 3월 두 번째 일요일부터 11월 첫 번째 일요일까지 적용됩니다. 이 제도는 아리조나주(나바호 네이션 제외), 하와이주, 그리고 몇몇 미국 영토(아메리칸 사모아, 괌, 북마리아나 제도, 푸에르토리코, 미국령 버진아일랜드)를 제외하고는 거의 모든 주에서 사용되고 있습니다.\n\n현재 미국의 시간을 확인하려면 특정 시간대를 기준으로 해야 합니다. 예를 들어, 동부 표준시(EST)를 기준으로 현재 시간을 확인해야 합니다. 온라인 시간 확인 도구나 스마트폰의 세계 시간 기능을 사용하면 쉽게 특정 시간대의 현재 시간을 알 수 있습니다.', name='Researcher')]}}
# ----
# {'supervisor': {'next': 'CurrentTime'}}
# ----
# {'CurrentTime': {'messages': [HumanMessage(content='현재 미국 각 시간대의 시간은 다음과 같습니다:\n\n1. **동부 표준시 (EST)**: 2024-09-25 17:15:26\n2. **중부 표준시 (CST)**: 2024-09-25 16:15:26\n3. **산악 표준시 (MST)**: 2024-09-25 15:15:26\n4. **태평양 표준시 (PST)**: 2024-09-25 14:15:26\n5. **알래스카 표준시 (AKST)**: 2024-09-25 13:15:26\n6. **하와이-알류샨 표준시 (HAST)**: 2024-09-25 11:15:26\n\n참고로, 일광 절약 시간제(DST)가 적용되는 경우 시간이 다를 수 있습니다.', name='CurrentTime')]}}
# ----
# {'supervisor': {'next': 'FINISH'}}
# ----

# %%
from IPython import display
display.Image("./langfuse_img/agent_graph.png")

# %%
# Add Langfuse handler as callback: config={"callbacks": [langfuse_handler]}
for s in graph_2.stream({"messages": [HumanMessage(content = "지금 몇시야?")]},
                      config={"callbacks": [langfuse_handler]}):
    print(s)
    print("----")
# Out:
# {'supervisor': {'next': 'CurrentTime'}}
# ----
# {'CurrentTime': {'messages': [HumanMessage(content='지금은 2024년 9월 25일 오후 5시 14분입니다.', name='CurrentTime')]}}
# ----
# {'supervisor': {'next': 'FINISH'}}
# ----

# %%
from IPython.display import Image, display
display(Image(graph_2.get_graph().draw_mermaid_png()))

# %%
from IPython import display
display.Image("./langfuse_img/traces.png")

# %% [markdown]
# ## Scoring

# %%
from langfuse.decorators import langfuse_context, observe
 
# Langfuse observe() decorator to automatically create a trace for the top-level function and spans for any nested functions.
@observe()
def research_agent(user_message):
    # Get callback handler scoped to this observed function
    lf_handler = langfuse_context.get_current_langchain_handler()
 
    # Trace langchain run via the Langfuse CallbackHandler
    response = graph_2.invoke({"messages": [HumanMessage(content=user_message)]},
                        config={"callbacks": [lf_handler]})
 
    # Score the entire trace e.g. to add user feedback
    langfuse_context.score_current_trace(
        name = "user-explicit-feedback",
        value = 1,
        comment = "그 시간은 정확해!"
        )
 
    return response

# %%
research_agent("지금 몇시야? ")
# Out:
# {'messages': [HumanMessage(content='지금 몇시야? '),
#   HumanMessage(content='지금 시각은 2024년 9월 25일 17시 18분 11초입니다.', name='CurrentTime')],
#  'next': 'FINISH'}

# %% [markdown]
# ## Ref
# https://langfuse.com/docs/integrations/langchain/example-python-langgraph
